# %% [markdown]
# # Pandas

# %%
# import pandas as pd
# pd.DataFrame({'name':['raks','raksha','rksha','raksha panwar'],'age':[22,23]},index=['one','two','three','four'])
# pd.Series([0,1,2,3,4],name='Emp ID',index=['A','B','C','D','E'])
# pd.read_csv('/titanic-training-data.csv')
# dataset_NAME.shape dataset_NAME.shape
# dataset_NAME.head()
# dataset_NAME.head(7)
# dataset_NAME.tail()
# dataset_NAME.tail(9)
# dataset_NAME.to_csv('new_CSV name')  -- saves dataset as CSV
# dataset_NAME.column_name
# dataset_NAME['column_name']
# dataset_NAME['column_name'][index] -- particular value
# dataset_NAME.iloc[0] -- 1st row 
# dataset_NAME.iloc[:,0] -- all rows first column
# dataset_NAME.iloc[:3,0] -- 3 row 1st col
# dataset_NAME.iloc[1:3,0] -- 2 rows 1st column
# dataset_NAME.iloc[[1,2,3],0] -- 1,2,3 rows & 1st col
# dataset_NAME.iloc[-5:] -- last 5 rows
# dataset_NAME.loc[0,'col_name'] - 1st row & col col_name
# dataset_NAME.loc[:,['col1','col2','col3']]
# dataset_NAME.set_index('name_for_index')
# dataset_NAME.col_name == 'value'  -- displays true or false
# dataset_NAME.loc[dataset_NAME.col_name == 'value']  -- displays rows for which colname=check_col_name
# dataset_NAME.loc[(dataset_NAME.col_name == 'value') & |  (dataset_NAME.col_name >= value )]  -- and or conditions
# dataset_NAME.loc[dataset_NAME.col_name.isin(['value1','value2'])]
# dataset_NAME.loc[dataset_NAME.col_name.notnull()]
# dataset_NAME['col_name']=value
# dataset_NAME['col_name'] = range(len(dataset_NAME),0,-1)
# --- 3rd

# %%
import pandas as pd

# %%
df1=pd.DataFrame({'name':['raks','raksha','rksha','raksha panwar'],'age':[22,23,24,25]},index=['one','two','three','four'])
df1
# Out:
#                 name  age
# one             raks   22
# two           raksha   23
# three          rksha   24
# four   raksha panwar   25

# %%
S1=pd.Series([0,1,2,3,4],name='Emp ID',index=['A','B','C','D','E'])
S1
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# Name: Emp ID, dtype: int64

# %%
d2=pd.read_csv('./titanic-training-data.csv')
d2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d2.shape
# Out:
# (891, 12)

# %%
d2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
d2.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d2.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
d2.tail(9)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# ...

# %%
d2.sample()
# Out:
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 694          695         0       1  Weir, Col. John  male  60.0      0      0
#
#      Ticket   Fare Cabin Embarked
# 694  113800  26.55   NaN        S

# %%
d2.to_csv('save_DataSet_to_CSV.csv')
