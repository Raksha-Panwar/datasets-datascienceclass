# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('CardioGoodFitness.csv')
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.shape
# Out:
# (180, 9)

# %%
df.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# ...

# %%
# top is mode column or column with max frequency
# unique works only on string (categorical) not numerical
# median - 50 %  25% - q1   75%- q3
# spread is most on income column and least on usage etc

# %%
df.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
# ///  = 73

# %%
# //

# %%
# spread is more

# %%
# max age

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 92    TM498   23  Female         14        Single      3        2   40932
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 169   TM798   30    Male         18     Partnered      5        5   99601
# 114   TM498   30  Female         13        Single      4        3   46617
# 145   TM798   23    Male         16        Single      4        5   48556
# 118   TM498   32    Male         16        Single      4        3   60261
# 156   TM798   25    Male         20     Partnered      4        5   74701
# 146   TM798   24    Male         16        Single      4        5   61006
# 38    TM195   26  Female         16        Single      3        3   36384
# 109   TM498   26  Female         16        Single      4        4   50028
#
#      Miles
# 92      53
# 170    260
# 169    150
# 114    106
# 145    100
# 118    127
# 156    170
# 146    100
# 38      66
# 109    127

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df['Product'].unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
df['Product'].nunique()
# Out:
# 3

# %%
df['Product'].value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
sns.countplot(x='Product',data=df)
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
sns.countplot(x='Gender' , data=df, palette='Set3')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['MaritalStatus'].unique()
# Out:
# array(['Single', 'Partnered'], dtype=object)

# %%
df['MaritalStatus'].nunique()
# Out:
# 2

# %%
df['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
sns.countplot(x='MaritalStatus',data=df)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
pd.crosstab(df['MaritalStatus'],df['Gender'])
# Out:
# Gender         Female  Male
# MaritalStatus
# Partnered          46    61
# Single             30    43

# %%
## mean can't be calculated for categorical 

# hist works only for numerical (int and float) dtypes

# %%
df.hist()
plt.show()

# %%
df.hist(figsize=(10,10),color='green')
plt.show()

# %%
sns.distplot(x=df['Age'])
plt.show()

# %%
sns.distplot(x=df['Age'],hist=False)
plt.show()

# %%
# box plot AKA five number summary

# %%
sns.boxplot(x='Age',data=df)
plt.show()

# %%
q3=33
q1=24
iqr=q3-q1
iqr
# Out:
# 9

# %%
#inference -> no outliers to left since no values below 18 which is min

q1-1.5*iqr
# Out:
# 10.5

# %%
#inference ->  outliers to right since values more than 46.5 are there and max is also an outlier


q3+1.5*iqr
# Out:
# 46.5

# %%
# inferenece

# 195 & 498 has both male and female customers
# 798 has mostly male customers

# %%
sns.countplot(x='Product',hue='Gender',data=df)
plt.show()

# %%
pd.crosstab(df['Product'],df['Gender'])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
sns.countplot(x='Product',hue='MaritalStatus',data=df)
plt.show()

# %%
pd.crosstab(df['Product'],df['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
# no inference related to tm s

# %%
sns.countplot(x='MaritalStatus',hue='Gender',data=df)
plt.show()

# %%
sns.boxplot(x='Product',y='Age',data=df)
plt.show()

# %%
# inference - 798 is used by high salaried employees > 50000

# 498 and 195 are less salaried

# %%
sns.boxplot(x='Product',y='Income',data=df)
plt.show()

# %%
# pair plot for corelation

# more miles more usage
# more mile more fitness
# upto certain age income increases then no relation

# %%
sns.pairplot(df)
plt.show()

# %%
# close to 1 -> good rltn
# close to 0 -> no rltn
# close to 0.5 -> moderate rltn

# -ve means 1 increasin other decreasing
# + means either both increasing or both descreasing

# %%
corr= df.corr()
corr
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
df1 = pd.read_csv('titanic-training-data.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
res=df1['Survived'].value_counts()
res
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
pd.crosstab(df1['Survived'],df1['Sex'])
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
sns.countplot(x='Survived',hue='Embarked',data=df1)
plt.show()

# %%
sns.countplot(x='Sex',hue='Survived',data=df1)
plt.show()

# %%
sns.boxplot(x='Embarked',y='Age',data=df1[93:119])
plt.show()

# %%
df1['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot(x='Pclass',hue='Survived',data=df1)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Sex',hue='Survived',data=df1)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Pclass',hue='Sex',data=df1)
plt.show()

# %%
sns.pairplot(df1)

# %%
corr1= df1.corr()
corr1
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(corr1, annot =True)
# Out:
# <Axes: >

# %%
df2= pd.read_csv('Automobile.csv')
df2
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
df2.drop(['engine_location', 'bore', 'symboling', 'length' ,'stroke','wheel_base'], axis='columns', inplace=True)
df2
# Out:
#      normalized_losses         make fuel_type aspiration number_of_doors  \
# 0                  168  alfa-romero       gas        std             two
# 1                  168  alfa-romero       gas        std             two
# 2                  168  alfa-romero       gas        std             two
# 3                  164         audi       gas        std            four
# 4                  164         audi       gas        std            four
# ..                 ...          ...       ...        ...             ...
# 196                 95        volvo       gas        std            four
# 197                 95        volvo       gas      turbo            four
# 198                 95        volvo       gas        std            four
# 199                 95        volvo    diesel      turbo            four
# 200                 95        volvo       gas      turbo            four
#
#       body_style drive_wheels  width  height  curb_weight engine_type  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   normalized_losses    201 non-null    int64
#  1   make                 201 non-null    object
#  2   fuel_type            201 non-null    object
#  3   aspiration           201 non-null    object
#  4   number_of_doors      201 non-null    object
#  5   body_style           201 non-null    object
#  6   drive_wheels         201 non-null    object
#  7   width                201 non-null    float64
#  8   height               201 non-null    float64
#  9   curb_weight          201 non-null    int64
#  10  engine_type          201 non-null    object
#  11  number_of_cylinders  201 non-null    object
#  12  engine_size          201 non-null    int64
#  13  fuel_system          201 non-null    object
#  14  compression_ratio    201 non-null    float64
# ...

# %%
sns.countplot(x='body_style',hue='engine_type',data=df2)
plt.show()

# %%
pd.crosstab(df2['body_style'],df2['engine_type'])
# Out:
# engine_type  dohc  l  ohc  ohcf  ohcv  rotor
# body_style
# convertible     2  0    2     1     1      0
# hardtop         0  0    5     2     1      0
# hatchback       4  1   52     3     4      4
# sedan           5  7   71     5     6      0
# wagon           1  4   15     4     1      0

# %%
pd.crosstab(df2['fuel_type'],df2['number_of_cylinders'])
# Out:
# number_of_cylinders  eight  five  four  six  three  twelve  two
# fuel_type
# diesel                   0     4    15    1      0       0    0
# gas                      4     6   142   23      1       1    4

# %%
sns.boxplot(x='number_of_cylinders', y='price', data=df2)
plt.show()

# %%
sns.boxplot(x='aspiration', y='price', data=df2)
plt.show()

# %%
sns.boxplot(x='body_style', y='price', data=df2)
plt.show()

# %%
sns.catplot(x ='body_style' , y='number_of_cylinders' , data=df2)
plt.show()
