# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('hotel_bookings.csv')
df.sample()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 98275  City Hotel            0          8               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 98275          September                        40                         25
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 98275                        2                     0       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 98275    No Deposit   28.0     NaN                    0     Transient  95.0
#
#        required_car_parking_spaces  total_of_special_requests  \
# 98275                            0                          0
#
#        reservation_status reservation_status_date
# 98275           Check-Out               9/27/2016
#
# [1 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
## removing company float type

# %%
df.drop(["company"],axis=1,inplace=True)
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.shape
# Out:
# (119390, 31)

# %%
## removing missing values in categorical datatype

# %%
mode1=df['country'].mode().values[0]
mode1
# Out:
# 'PRT'

# %%
df['country']=df['country'].replace(np.nan,mode1)

# %%
df['country'].isnull().sum()
# Out:
# 0

# %%
# agent missing values removal with median

# %%
median1=df['agent'].median()
median1
# Out:
# 14.0

# %%
df['agent']=df['agent'].replace(np.nan,median1)

# %%
df['agent'].isnull().sum()
# Out:
# 0

# %%
# children missing values removal with mean

# %%
mean1=df['children'].mean()
mean1
# Out:
# 0.10388990333874994

# %%
df['children']=df['children'].replace(np.nan,mean1)

# %%
df['children'].isnull().sum()
# Out:
# 0

# %%
# handling duplicate values

# %%
duplicates= df.duplicated()
print(duplicates.sum())
df[duplicates][:5]
# Out:
# 32020
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 5    Resort Hotel            0         14               2015
# 22   Resort Hotel            0         72               2015
# 43   Resort Hotel            0         70               2015
# 138  Resort Hotel            1          5               2015
# 200  Resort Hotel            0          0               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 5                 July                        27                          1
# 22                July                        27                          1
# 43                July                        27                          2
# 138               July                        28                          5
# 200               July                        28                          7
#
#      stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 5                          0                     2       2  ...
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
dups=df.duplicated()
dups.sum()
# Out:
# 0

# %%
df.shape
# Out:
# (87370, 31)

# %%
## handling or removing outliers

# %%
df.boxplot(column=["lead_time"])
# Out:
# <Axes: >

# %%
def remove_outliers(col):
    sorted(col)
    q1,q3=col.quantile([0.25,0.75])
    iqr=q3-q1
    lower_range=q1-(1.5*iqr)
    upper_range=q3+(1.5*iqr)
    return lower_range, upper_range

# %%
lower_lead, upper_lead=remove_outliers(df['lead_time'])

# %%
df['lead_time']=np.where(df['lead_time']>upper_lead, upper_lead, df['lead_time'])
df['lead_time']=np.where(df['lead_time']<lower_lead, lower_lead, df['lead_time'])

# %%
df.boxplot(column=["lead_time"])
plt.show()

# %%
df=pd.get_dummies(df,columns=['hotel','arrival_date_month','meal','country','market_segment','distribution_channel','reserved_room_type','assigned_room_type','deposit_type','customer_type','reservation_status','reservation_status_date'])

# %%
df.head(10)
# Out:
#     is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0             0      296.0               2015                        27
# 1             0      296.0               2015                        27
# 2             0        7.0               2015                        27
# 3             0       13.0               2015                        27
# 4             0       14.0               2015                        27
# 6             0        0.0               2015                        27
# 7             0        9.0               2015                        27
# 8             1       85.0               2015                        27
# 9             1       75.0               2015                        27
# 10            1       23.0               2015                        27
#
#     arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 0                           1                        0                     0
# ...

# %%
#try same with mpg dataset
